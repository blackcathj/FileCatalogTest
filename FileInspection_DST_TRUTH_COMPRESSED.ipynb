# %%
# imports to write dynamic markdown contents
import os
from IPython.display import display, Markdown, Latex
from IPython.display import HTML

# %%
# turn off/on code for the result HTML page

display(Markdown('*For the result HTML page:* '))
    
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# *For the result HTML page:*
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.24/06

# %%
import uproot

import pandas as pd
import os
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.colors
import numpy as np
import glob
mpl.style.use('seaborn-talk')

# %%
OFFLINE_MAIN = os.getenv("OFFLINE_MAIN")
if OFFLINE_MAIN is not None:
    display(Markdown(f"via sPHENIX software distribution at `{OFFLINE_MAIN}`"))
# Out:
# via sPHENIX software distribution at `/cvmfs/sphenix.sdcc.bnl.gov/gcc-8.3/release/release_new/new.3`

# %%
ROOT.gSystem.Load("libg4dst")
ROOT.gSystem.Load("libfun4all")
# Out:
# 0

# %%
# DST_TRUTH_pythia8_pp_mb_3MHz = ROOT.TFile.Open("/sphenix/sim/sim01/sphnxpro/mdc2/hf_pp200_signal/tracks/charm/DST_TRUTH_pythia8_pp_mb_3MHz-0000000004-00004.root")

# %%
# %%cpp -d
#
# #include <fun4all/Fun4AllDstInputManager.h>
# #include <fun4all/Fun4AllInputManager.h>
# #include <fun4all/Fun4AllServer.h>
# #include <fun4all/SubsysReco.h>
#
# #include <TSystem.h>

# %%
# %%cpp
#
# {
#   Fun4AllServer *se = Fun4AllServer::instance();
#
#   Fun4AllInputManager *in = new Fun4AllDstInputManager("DSTin");
#   in->fileopen("DST_TRUTH_COMPRESSED-0000000004-00000.root");
#   se->registerInputManager(in);
#
#   se->run(1);
#   se->End();
# }
# Out:
# Fun4AllServer::setRun(): could not get timestamp for run  4, using tics(0) timestamp: Wed Dec 31 19:00:00 1969
# --------------------------------------
#
# List of Nodes in Fun4AllServer:
# Node Tree under TopNode TOP
# TOP (PHCompositeNode)/
#    DST (PHCompositeNode)/
#       Sync (IO,SyncObjectv1)
#       EventHeader (IO,EventHeaderv1)
#       HCALIN (PHCompositeNode)/
#          TOWER_SIM_HCALIN (IO,RawTowerContainer)
#          TOWER_RAW_HCALIN (IO,RawTowerContainer)
#          TOWER_CALIB_HCALIN (IO,RawTowerContainer)
#          CLUSTER_HCALIN (IO,RawClusterContainer)
#          G4HIT_HCALIN (IO,PHG4HitContainer)
#       HCALOUT (PHCompositeNode)/
#          TOWER_SIM_HCALOUT (IO,RawTowerContainer)
#          TOWER_RAW_HCALOUT (IO,RawTowerContainer)
#          TOWER_CALIB_HCALOUT (IO,RawTowerContainer)
#          CLUSTER_HCALOUT (IO,RawClusterContainer)
#          G4HIT_HCALOUT (IO,PHG4HitContainer)
#       GLOBAL (PHCompositeNode)/
#          GlobalVertexMap (IO,GlobalVertexMapv1)
#       CEMC (PHCompositeNode)/
#          TOWER_SIM_CEMC (IO,RawTowerContainer)
#          TOWER_RAW_CEMC (IO,RawTowerContainer)
#          TOWER_CALIB_CEMC (IO,RawTowerContainer)
#          CLUSTER_CEMC (IO,RawClusterContainer)
#          CLUSTER_POS_COR_CEMC (IO,RawClusterContainer)
#       BBC (PHCompositeNode)/
#          G4HIT_BBC (IO,PHG4HitContainer)
#       EPD (PHCompositeNode)/
#          G4HIT_EPD (IO,PHG4HitContainer)
#       G4HIT_CEMC (IO,PHG4HitContainer)
#       MVTX (PHCompositeNode)/
#          G4HIT_MVTX (IO,PHG4HitContainer)
#       INTT (PHCompositeNode)/
#          G4HIT_INTT (IO,PHG4HitContainer)
#       TPC (PHCompositeNode)/
#          G4HIT_TPC (IO,PHG4HitContainer)
#       MICROMEGAS (PHCompositeNode)/
#          G4HIT_MICROMEGAS (IO,PHG4HitContainer)
#       PHHepMCGenEventMap (IO,PHHepMCGenEventMap)
#       G4HIT_BH_1 (IO,PHG4HitContainer)
#       G4TruthInfo (IO,PHG4TruthInfoContainer)
#       TRKR (PHCompositeNode)/
#          TRKR_CLUSTER (IO,TrkrClusterContainerv3)
#          TRKR_CLUSTERHITASSOC (IO,TrkrClusterHitAssocv3)
#          TRKR_HITSET (IO,TrkrHitSetContainerv1)
#          TRKR_HITTRUTHASSOC (IO,TrkrHitTruthAssocv1)
#       SVTX (PHCompositeNode)/
#          SvtxSiliconTrackMap (IO,SvtxTrackMap_v1)
#          SvtxTrackMap (IO,SvtxTrackMap_v1)
#          AssocInfoContainer (IO,AssocInfoContainerv1)
#          TpcSeedTrackMap (IO,TpcSeedTrackMapv1)
#          SvtxVertexMap (IO,SvtxVertexMap_v1)
#          SvtxVertexMapRave (IO,SvtxVertexMap_v1)
#          PHG4ParticleSvtxMap (IO,PHG4ParticleSvtxMap_v1)
#          SvtxPHG4ParticleMap (IO,SvtxPHG4ParticleMap_v1)
#    RUN (PHCompositeNode)/
#       PHGenIntegral (IO,PHGenIntegralv1)
#       RunHeader (IO,RunHeaderv1)
#       Flags (IO,FlagSavev1)
#       FIELD_CONFIG (IO,PHFieldConfigv1)
#       PIPE (PHCompositeNode)/
#          G4GEOPARAM_PIPE (IO,PdbParameterMapContainer)
#       MVTX (PHCompositeNode)/
#          G4GEOPARAM_MVTX (IO,PdbParameterMapContainer)
#       INTT (PHCompositeNode)/
#          G4GEOPARAM_INTT (IO,PdbParameterMapContainer)
#          DEADMAP_INTT (IO,InttDeadMapv1)
#          G4CELLPARAM_INTT (IO,PdbParameterMap)
#       TPC (PHCompositeNode)/
#          G4GEOPARAM_TPC (IO,PdbParameterMapContainer)
#          G4CELLPARAM_TPC (IO,PdbParameterMap)
#          G4TPCPADPLANE (IO,PdbParameterMap)
#       TPC_ENDCAP (PHCompositeNode)/
#          G4GEOPARAM_TPC_ENDCAP (IO,PdbParameterMapContainer)
#       MICROMEGAS (PHCompositeNode)/
#          G4GEOPARAM_MICROMEGAS (IO,PdbParameterMapContainer)
#       BBC (PHCompositeNode)/
#          G4GEOPARAM_BBC (IO,PdbParameterMapContainer)
#       CEMC_ELECTRONICS (PHCompositeNode)/
#          G4GEOPARAM_CEMC_ELECTRONICS (IO,PdbParameterMapContainer)
#       CEMC_SPT (PHCompositeNode)/
#          G4GEOPARAM_CEMC_SPT (IO,PdbParameterMapContainer)
#       CEMC (PHCompositeNode)/
#          G4GEOPARAM_CEMC (IO,PdbParameterMapContainer)
#          G4CELLPARAM_CEMC (IO,PdbParameterMap)
#          TOWERGEOM_CEMC (IO,RawTowerGeomContainer_Cylinderv1)
#       HCALIN (PHCompositeNode)/
#          G4GEOPARAM_HCALIN (IO,PdbParameterMapContainer)
#          G4CELLPARAM_HCALIN (IO,PdbParameterMap)
#          TOWERPARAM_HCALIN (IO,PdbParameterMap)
#          TOWERGEOM_HCALIN (IO,RawTowerGeomContainer_Cylinderv1)
#       HCALIN_SPT (PHCompositeNode)/
#          G4GEOPARAM_HCALIN_SPT (IO,PdbParameterMapContainer)
#       MAGNET (PHCompositeNode)/
#          G4GEOPARAM_MAGNET (IO,PdbParameterMapContainer)
#       HCALOUT (PHCompositeNode)/
#          G4GEOPARAM_HCALOUT (IO,PdbParameterMapContainer)
#          G4CELLPARAM_HCALOUT (IO,PdbParameterMap)
#          TOWERPARAM_HCALOUT (IO,PdbParameterMap)
#          TOWERGEOM_HCALOUT (IO,RawTowerGeomContainer_Cylinderv1)
#       EPD (PHCompositeNode)/
#          G4GEOPARAM_EPD (IO,PdbParameterMapContainer)
#       G4GEOPARAM_BH_1 (IO,PdbParameterMapContainer)
#       CYLINDERGEOM_BH_1 (IO,PHG4CylinderGeomContainer)
#       BH_FORWARD_PLUS (PHCompositeNode)/
#          G4GEOPARAM_BH_FORWARD_PLUS (IO,PdbParameterMapContainer)
#       BH_FORWARD_NEG (PHCompositeNode)/
#          G4GEOPARAM_BH_FORWARD_NEG (IO,PdbParameterMapContainer)
#       CYLINDERGEOM_MVTX (IO,PHG4CylinderGeomContainer)
#       CYLINDERGEOM_INTT (IO,PHG4CylinderGeomContainer)
#       CYLINDERGEOM_MICROMEGAS_FULL (IO,PHG4CylinderGeomContainer)
#       CYLINDERGEOM_CEMC (IO,PHG4CylinderGeomContainer)
#       GEOMETRY_IO (IO,PHGeomIOTGeo)
#       CYLINDERCELLGEOM_CEMC (IO,PHG4CylinderCellGeomContainer)
#       eclus_Recalibration_CEMC (IO,PdbParameterMap)
#       ecore_Recalibration_CEMC (IO,PdbParameterMap)
#       CYLINDERCELLGEOM_SVTX (IO,PHG4CylinderCellGeomContainer)
#    PAR (PHCompositeNode)/
# Warning in <TClass::Init>: no dictionary for class pair<int,PHG4CylinderGeom_Spacalv3::geom_tower> is available

# %%
ROOT.gFile.ls()
# Out:
# TFile**		./DST_TRUTH_COMPRESSED-0000000004-00000.root	titled by PHOOL
#  TFile*		./DST_TRUTH_COMPRESSED-0000000004-00000.root	titled by PHOOL
#   OBJ: TTree	T0x8fa4ee0	titled by PHOOL : 0 at: 0x8a9fc00
#   KEY: TTree	T;2	titled by PHOOL [current cycle]
#   KEY: TTree	T;1	titled by PHOOL [backup cycle]
#   KEY: TTree	T1;1	titled by PHOOL

# %%
# %%capture captured

ROOT.gFile.T.Print()
# Out:
# ******************************************************************************
# *Tree    :T         : titled by PHOOL                                        *
# *Entries :       10 : Total =       970048793 bytes  File  Size =  125910931 *
# *        :          : Tree compression factor =   7.70                       *
# ******************************************************************************
# *Branch  :DST#Sync                                                           *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br    0 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    1 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    2 :eventcounter : Int_t                                               *
# *Entries :       10 : Total  Size=        861 bytes  File Size  =        344 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    3 :eventnumber : Int_t                                                *
# *Entries :       10 : Total  Size=        853 bytes  File Size  =        340 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    4 :runnumber : Int_t                                                  *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    5 :segmentnumber : Int_t                                              *
# *Entries :       10 : Total  Size=        869 bytes  File Size  =        348 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Branch  :DST#EventHeader                                                    *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br    6 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    7 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    8 :RunNumber : Int_t                                                  *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    9 :EvtSequence : Int_t                                                *
# *Entries :       10 : Total  Size=        853 bytes  File Size  =        340 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   10 :m_IntEventProperties : Int_t m_IntEventProperties_                 *
# *Entries :       10 : Total  Size=       2840 bytes  File Size  =        445 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.01     *
# *............................................................................*
# *Br   11 :m_IntEventProperties.first : string first[m_IntEventProperties_]   *
# *Entries :       10 : Total  Size=       1171 bytes  File Size  =        492 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   12 :m_IntEventProperties.second : Long_t second[m_IntEventProperties_] *
# *Entries :       10 : Total  Size=       1119 bytes  File Size  =        436 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   13 :m_FloatEventProperties : Int_t m_FloatEventProperties_             *
# *Entries :       10 : Total  Size=       2881 bytes  File Size  =        453 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.01     *
# *............................................................................*
# *Br   14 :m_FloatEventProperties.first :                                     *
# *         | string first[m_FloatEventProperties_]                            *
# *Entries :       10 : Total  Size=       1191 bytes  File Size  =        500 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   15 :m_FloatEventProperties.second :                                    *
# *         | Float_t second[m_FloatEventProperties_]                          *
# *Entries :       10 : Total  Size=       1139 bytes  File Size  =        444 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Branch  :DST#HCALIN#TOWER_SIM_HCALIN                                        *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   16 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   17 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   18 :_caloid   : Int_t                                                  *
# *Entries :       10 : Total  Size=        821 bytes  File Size  =        324 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   19 :_towers   : Int_t _towers_                                         *
# *Entries :       10 : Total  Size=       2669 bytes  File Size  =        396 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   20 :_towers.first : UInt_t first[_towers_]                             *
# *Entries :       10 : Total  Size=       3813 bytes  File Size  =       1937 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.66     *
# *............................................................................*
# *Br   21 :_towers.second : RawTower* second[_towers_]                        *
# *Entries :       10 : Total  Size=      63999 bytes  File Size  =      12663 *
# *Baskets :        6 : Basket Size=      10752 bytes  Compression=   5.01     *
# *............................................................................*
# *Branch  :DST#HCALIN#TOWER_RAW_HCALIN                                        *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   22 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   23 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   24 :_caloid   : Int_t                                                  *
# *Entries :       10 : Total  Size=        821 bytes  File Size  =        324 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   25 :_towers   : Int_t _towers_                                         *
# *Entries :       10 : Total  Size=       2689 bytes  File Size  =        396 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   26 :_towers.first : UInt_t first[_towers_]                             *
# *Entries :       10 : Total  Size=      11269 bytes  File Size  =       5689 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.88     *
# *............................................................................*
# *Br   27 :_towers.second : RawTower* second[_towers_]                        *
# *Entries :       10 : Total  Size=     255955 bytes  File Size  =      15725 *
# *Baskets :       10 : Basket Size=      43520 bytes  Compression=  16.24     *
# *............................................................................*
# *Branch  :DST#HCALIN#TOWER_CALIB_HCALIN                                      *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   28 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   29 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   30 :_caloid   : Int_t                                                  *
# *Entries :       10 : Total  Size=        821 bytes  File Size  =        324 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   31 :_towers   : Int_t _towers_                                         *
# *Entries :       10 : Total  Size=       2689 bytes  File Size  =        396 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   32 :_towers.first : UInt_t first[_towers_]                             *
# *Entries :       10 : Total  Size=      11269 bytes  File Size  =       5689 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.88     *
# *............................................................................*
# *Br   33 :_towers.second : RawTower* second[_towers_]                        *
# *Entries :       10 : Total  Size=     255955 bytes  File Size  =      16323 *
# *Baskets :       10 : Basket Size=      43520 bytes  Compression=  15.64     *
# *............................................................................*
# *Branch  :DST#HCALIN#CLUSTER_HCALIN                                          *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   34 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   35 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   36 :_clusters : Int_t _clusters_                                       *
# *Entries :       10 : Total  Size=       2719 bytes  File Size  =        404 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   37 :_clusters.first : UInt_t first[_clusters_]                         *
# *Entries :       10 : Total  Size=       1189 bytes  File Size  =        478 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.21     *
# *............................................................................*
# *Br   38 :_clusters.second : RawCluster* second[_clusters_]                  *
# *Entries :       10 : Total  Size=       6220 bytes  File Size  =       2367 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   2.37     *
# *............................................................................*
# *Branch  :DST#HCALIN#G4HIT_HCALIN                                            *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   39 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   40 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   41 :id        : Int_t                                                  *
# *Entries :       10 : Total  Size=        781 bytes  File Size  =        304 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   42 :hitmap    : Int_t hitmap_                                          *
# *Entries :       10 : Total  Size=       2629 bytes  File Size  =        389 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.01     *
# *............................................................................*
# *Br   43 :hitmap.first : ULong64_t first[hitmap_]                            *
# *Entries :       10 : Total  Size=        971 bytes  File Size  =        376 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   44 :hitmap.second : PHG4Hit* second[hitmap_]                           *
# *Entries :       10 : Total  Size=        979 bytes  File Size  =        380 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   45 :layers    : set<unsigned int>                                      *
# *Entries :       10 : Total  Size=      11185 bytes  File Size  =       2158 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   4.95     *
# *............................................................................*
# *Branch  :DST#HCALOUT#TOWER_SIM_HCALOUT                                      *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   46 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   47 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   48 :_caloid   : Int_t                                                  *
# *Entries :       10 : Total  Size=        821 bytes  File Size  =        324 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   49 :_towers   : Int_t _towers_                                         *
# *Entries :       10 : Total  Size=       2669 bytes  File Size  =        396 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   50 :_towers.first : UInt_t first[_towers_]                             *
# *Entries :       10 : Total  Size=       2793 bytes  File Size  =       1458 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.50     *
# *............................................................................*
# *Br   51 :_towers.second : RawTower* second[_towers_]                        *
# *Entries :       10 : Total  Size=      41209 bytes  File Size  =       8409 *
# *Baskets :        5 : Basket Size=       9149 bytes  Compression=   4.83     *
# *............................................................................*
# *Branch  :DST#HCALOUT#TOWER_RAW_HCALOUT                                      *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   52 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   53 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   54 :_caloid   : Int_t                                                  *
# *Entries :       10 : Total  Size=        821 bytes  File Size  =        324 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   55 :_towers   : Int_t _towers_                                         *
# *Entries :       10 : Total  Size=       2689 bytes  File Size  =        396 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   56 :_towers.first : UInt_t first[_towers_]                             *
# *Entries :       10 : Total  Size=      11229 bytes  File Size  =       5683 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.87     *
# *............................................................................*
# *Br   57 :_towers.second : RawTower* second[_towers_]                        *
# *Entries :       10 : Total  Size=     254455 bytes  File Size  =      14932 *
# *Baskets :       10 : Basket Size=      40960 bytes  Compression=  17.00     *
# *............................................................................*
# *Branch  :DST#HCALOUT#TOWER_CALIB_HCALOUT                                    *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   58 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   59 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   60 :_caloid   : Int_t                                                  *
# *Entries :       10 : Total  Size=        821 bytes  File Size  =        324 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   61 :_towers   : Int_t _towers_                                         *
# *Entries :       10 : Total  Size=       2689 bytes  File Size  =        396 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   62 :_towers.first : UInt_t first[_towers_]                             *
# *Entries :       10 : Total  Size=      11229 bytes  File Size  =       5683 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.87     *
# *............................................................................*
# *Br   63 :_towers.second : RawTower* second[_towers_]                        *
# *Entries :       10 : Total  Size=     254455 bytes  File Size  =      15415 *
# *Baskets :       10 : Basket Size=      40960 bytes  Compression=  16.47     *
# *............................................................................*
# *Branch  :DST#HCALOUT#CLUSTER_HCALOUT                                        *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   64 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   65 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   66 :_clusters : Int_t _clusters_                                       *
# *Entries :       10 : Total  Size=       2719 bytes  File Size  =        404 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   67 :_clusters.first : UInt_t first[_clusters_]                         *
# *Entries :       10 : Total  Size=       1237 bytes  File Size  =        521 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.20     *
# *............................................................................*
# *Br   68 :_clusters.second : RawCluster* second[_clusters_]                  *
# *Entries :       10 : Total  Size=       7387 bytes  File Size  =       2583 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   2.62     *
# *............................................................................*
# *Branch  :DST#HCALOUT#G4HIT_HCALOUT                                          *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   69 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   70 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   71 :id        : Int_t                                                  *
# *Entries :       10 : Total  Size=        781 bytes  File Size  =        304 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   72 :hitmap    : Int_t hitmap_                                          *
# *Entries :       10 : Total  Size=       2629 bytes  File Size  =        389 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.01     *
# *............................................................................*
# *Br   73 :hitmap.first : ULong64_t first[hitmap_]                            *
# *Entries :       10 : Total  Size=        971 bytes  File Size  =        376 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   74 :hitmap.second : PHG4Hit* second[hitmap_]                           *
# *Entries :       10 : Total  Size=        979 bytes  File Size  =        380 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   75 :layers    : set<unsigned int>                                      *
# *Entries :       10 : Total  Size=      13745 bytes  File Size  =       2724 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   4.86     *
# *............................................................................*
# *Branch  :DST#GLOBAL#GlobalVertexMap                                         *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   76 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   77 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   78 :_map      : Int_t _map_                                            *
# *Entries :       10 : Total  Size=       2635 bytes  File Size  =        384 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   79 :_map.first : UInt_t first[_map_]                                   *
# *Entries :       10 : Total  Size=        991 bytes  File Size  =        405 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.01     *
# *............................................................................*
# *Br   80 :_map.second : GlobalVertex* second[_map_]                          *
# *Entries :       10 : Total  Size=       2149 bytes  File Size  =        915 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.71     *
# *............................................................................*
# *Branch  :DST#CEMC#TOWER_SIM_CEMC                                            *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   81 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   82 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   83 :_caloid   : Int_t                                                  *
# *Entries :       10 : Total  Size=        821 bytes  File Size  =        324 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   84 :_towers   : Int_t _towers_                                         *
# *Entries :       10 : Total  Size=       2669 bytes  File Size  =        396 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   85 :_towers.first : UInt_t first[_towers_]                             *
# *Entries :       10 : Total  Size=       8121 bytes  File Size  =       4255 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.77     *
# *............................................................................*
# *Br   86 :_towers.second : RawTower* second[_towers_]                        *
# *Entries :       10 : Total  Size=     158533 bytes  File Size  =      29019 *
# *Baskets :        7 : Basket Size=      23040 bytes  Compression=   5.44     *
# *............................................................................*
# *Branch  :DST#CEMC#TOWER_RAW_CEMC                                            *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   87 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   88 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   89 :_caloid   : Int_t                                                  *
# *Entries :       10 : Total  Size=        821 bytes  File Size  =        324 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   90 :_towers   : Int_t _towers_                                         *
# *Entries :       10 : Total  Size=       2689 bytes  File Size  =        396 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   91 :_towers.first : UInt_t first[_towers_]                             *
# *Entries :       10 : Total  Size=      32655 bytes  File Size  =      16858 *
# *Baskets :        6 : Basket Size=       9149 bytes  Compression=   1.90     *
# *............................................................................*
# *Br   92 :_towers.second : RawTower* second[_towers_]                        *
# *Entries :       10 : Total  Size=     778339 bytes  File Size  =      43534 *
# *Baskets :       10 : Basket Size=     129536 bytes  Compression=  17.86     *
# *............................................................................*
# *Branch  :DST#CEMC#TOWER_CALIB_CEMC                                          *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   93 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   94 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   95 :_caloid   : Int_t                                                  *
# *Entries :       10 : Total  Size=        821 bytes  File Size  =        324 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   96 :_towers   : Int_t _towers_                                         *
# *Entries :       10 : Total  Size=       2689 bytes  File Size  =        396 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   97 :_towers.first : UInt_t first[_towers_]                             *
# *Entries :       10 : Total  Size=      32655 bytes  File Size  =      16858 *
# *Baskets :        6 : Basket Size=       9149 bytes  Compression=   1.90     *
# *............................................................................*
# *Br   98 :_towers.second : RawTower* second[_towers_]                        *
# *Entries :       10 : Total  Size=     778339 bytes  File Size  =      70424 *
# *Baskets :       10 : Basket Size=     129536 bytes  Compression=  11.04     *
# *............................................................................*
# *Branch  :DST#CEMC#CLUSTER_CEMC                                              *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   99 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  100 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  101 :_clusters : Int_t _clusters_                                       *
# *Entries :       10 : Total  Size=       2739 bytes  File Size  =        404 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  102 :_clusters.first : UInt_t first[_clusters_]                         *
# *Entries :       10 : Total  Size=      29569 bytes  File Size  =       5688 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   5.09     *
# *............................................................................*
# *Br  103 :_clusters.second : RawCluster* second[_clusters_]                  *
# *Entries :       10 : Total  Size=     743289 bytes  File Size  =     186521 *
# *Baskets :       10 : Basket Size=     123392 bytes  Compression=   3.98     *
# *............................................................................*
# *Branch  :DST#CEMC#CLUSTER_POS_COR_CEMC                                      *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br  104 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  105 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  106 :_clusters : Int_t _clusters_                                       *
# *Entries :       10 : Total  Size=       2739 bytes  File Size  =        404 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  107 :_clusters.first : UInt_t first[_clusters_]                         *
# *Entries :       10 : Total  Size=      29569 bytes  File Size  =       5688 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   5.09     *
# *............................................................................*
# *Br  108 :_clusters.second : RawCluster* second[_clusters_]                  *
# *Entries :       10 : Total  Size=     743289 bytes  File Size  =     209950 *
# *Baskets :       10 : Basket Size=     123392 bytes  Compression=   3.54     *
# *............................................................................*
# *Branch  :DST#BBC#G4HIT_BBC                                                  *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br  109 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  110 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  111 :id        : Int_t                                                  *
# *Entries :       10 : Total  Size=        781 bytes  File Size  =        304 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  112 :hitmap    : Int_t hitmap_                                          *
# *Entries :       10 : Total  Size=       2669 bytes  File Size  =        392 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  113 :hitmap.first : ULong64_t first[hitmap_]                            *
# *Entries :       10 : Total  Size=     258135 bytes  File Size  =      66019 *
# *Baskets :       10 : Basket Size=      41984 bytes  Compression=   3.90     *
# *............................................................................*
# *Br  114 :hitmap.second : PHG4Hit* second[hitmap_]                           *
# *Entries :       10 : Total  Size=    3851209 bytes  File Size  =    1508509 *
# *Baskets :       10 : Basket Size=     621056 bytes  Compression=   2.55     *
# *............................................................................*
# *Br  115 :layers    : set<unsigned int>                                      *
# *Entries :       10 : Total  Size=       6057 bytes  File Size  =       1312 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   4.24     *
# *............................................................................*
# *Branch  :DST#EPD#G4HIT_EPD                                                  *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br  116 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  117 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  118 :id        : Int_t                                                  *
# *Entries :       10 : Total  Size=        781 bytes  File Size  =        304 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  119 :hitmap    : Int_t hitmap_                                          *
# *Entries :       10 : Total  Size=       2669 bytes  File Size  =        392 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  120 :hitmap.first : ULong64_t first[hitmap_]                            *
# *Entries :       10 : Total  Size=     481919 bytes  File Size  =     124134 *
# *Baskets :       10 : Basket Size=      80384 bytes  Compression=   3.88     *
# *............................................................................*
# *Br  121 :hitmap.second : PHG4Hit* second[hitmap_]                           *
# *Entries :       10 : Total  Size=    6907704 bytes  File Size  =    2880130 *
# *Baskets :       10 : Basket Size=    1150976 bytes  Compression=   2.40     *
# *............................................................................*
# *Br  122 :layers    : set<unsigned int>                                      *
# *Entries :       10 : Total  Size=      30589 bytes  File Size  =       6358 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   4.73     *
# *............................................................................*
# *Branch  :DST#G4HIT_CEMC                                                     *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br  123 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  124 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  125 :id        : Int_t                                                  *
# *Entries :       10 : Total  Size=        781 bytes  File Size  =        304 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  126 :hitmap    : Int_t hitmap_                                          *
# *Entries :       10 : Total  Size=       2629 bytes  File Size  =        389 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.01     *
# *............................................................................*
# *Br  127 :hitmap.first : ULong64_t first[hitmap_]                            *
# *Entries :       10 : Total  Size=        971 bytes  File Size  =        376 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  128 :hitmap.second : PHG4Hit* second[hitmap_]                           *
# *Entries :       10 : Total  Size=        979 bytes  File Size  =        380 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  129 :layers    : set<unsigned int>                                      *
# *Entries :       10 : Total  Size=        985 bytes  File Size  =        441 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.12     *
# *............................................................................*
# *Branch  :DST#MVTX#G4HIT_MVTX                                                *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br  130 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  131 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  132 :id        : Int_t                                                  *
# *Entries :       10 : Total  Size=        781 bytes  File Size  =        304 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  133 :hitmap    : Int_t hitmap_                                          *
# *Entries :       10 : Total  Size=       2629 bytes  File Size  =        389 *
# ...
# *Br  204 :m_map     : Int_t m_map_                                           *
# *Entries :       10 : Total  Size=       3436 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  205 :m_map.first : UInt_t first[m_map_]                                 *
# *Entries :       10 : Total  Size=  120109703 bytes  File Size  =     700969 *
# *Baskets :       10 : Basket Size=    4574651 bytes  Compression= 171.35     *
# *............................................................................*
# *Br  206 :m_map.second.first : UInt_t first[m_map_]                          *
# *Entries :       10 : Total  Size=  120109787 bytes  File Size  =   32400937 *
# *Baskets :       10 : Basket Size=    4574651 bytes  Compression=   3.71     *
# *............................................................................*
# *Br  207 :m_map.second.second : ULong64_t second[m_map_]                     *
# *Entries :       10 : Total  Size=  240218025 bytes  File Size  =    7567370 *
# *Baskets :       10 : Basket Size=    4574651 bytes  Compression=  31.74     *
# *............................................................................*
# *Branch  :DST#SVTX#SvtxSiliconTrackMap                                       *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br  208 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  209 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  210 :_map      : Int_t _map_                                            *
# *Entries :       10 : Total  Size=       2616 bytes  File Size  =        384 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  211 :_map.first : UInt_t first[_map_]                                   *
# *Entries :       10 : Total  Size=       8335 bytes  File Size  =       1850 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   4.19     *
# *............................................................................*
# *Br  212 :_map.second : SvtxTrack* second[_map_]                             *
# *Entries :       10 : Total  Size=     991291 bytes  File Size  =      87724 *
# *Baskets :        8 : Basket Size=     182784 bytes  Compression=  11.29     *
# *............................................................................*
# *Branch  :DST#SVTX#SvtxTrackMap                                              *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br  213 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  214 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  215 :_map      : Int_t _map_                                            *
# *Entries :       10 : Total  Size=       2616 bytes  File Size  =        384 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  216 :_map.first : UInt_t first[_map_]                                   *
# *Entries :       10 : Total  Size=       5603 bytes  File Size  =       2246 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   2.24     *
# *............................................................................*
# *Br  217 :_map.second : SvtxTrack* second[_map_]                             *
# *Entries :       10 : Total  Size=    7697664 bytes  File Size  =    5125406 *
# *Baskets :        8 : Basket Size=    1363456 bytes  Compression=   1.50     *
# *............................................................................*
# *Branch  :DST#SVTX#AssocInfoContainer                                        *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br  218 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  219 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  220 :_map_cluster_id_track_id : Int_t _map_cluster_id_track_id_         *
# *Entries :       10 : Total  Size=       3001 bytes  File Size  =        464 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  221 :_map_cluster_id_track_id.first :                                   *
# *         | ULong_t first[_map_cluster_id_track_id_]                         *
# *Entries :       10 : Total  Size=       8479 bytes  File Size  =       2730 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   2.85     *
# *............................................................................*
# *Br  222 :_map_cluster_id_track_id.second :                                  *
# *         | UInt_t second[_map_cluster_id_track_id_]                         *
# *Entries :       10 : Total  Size=       4823 bytes  File Size  =       1066 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   3.86     *
# *............................................................................*
# *Branch  :DST#SVTX#TpcSeedTrackMap                                           *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br  223 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  224 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  225 :SeedTrackMap : Int_t SeedTrackMap_                                 *
# *Entries :       10 : Total  Size=       2774 bytes  File Size  =        416 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  226 :SeedTrackMap.first : UInt_t first[SeedTrackMap_]                   *
# *Entries :       10 : Total  Size=       7519 bytes  File Size  =       2579 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   2.67     *
# *............................................................................*
# *Br  227 :SeedTrackMap.second : UInt_t second[SeedTrackMap_]                 *
# *Entries :       10 : Total  Size=       7527 bytes  File Size  =       2595 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   2.66     *
# *............................................................................*
# *Branch  :DST#SVTX#SvtxVertexMap                                             *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br  228 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  229 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  230 :_map      : Int_t _map_                                            *
# *Entries :       10 : Total  Size=       2623 bytes  File Size  =        384 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  231 :_map.first : UInt_t first[_map_]                                   *
# *Entries :       10 : Total  Size=        991 bytes  File Size  =        405 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.01     *
# *............................................................................*
# *Br  232 :_map.second : SvtxVertex* second[_map_]                            *
# *Entries :       10 : Total  Size=       2243 bytes  File Size  =       1157 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.43     *
# *............................................................................*
# *Branch  :DST#SVTX#SvtxVertexMapRave                                         *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br  233 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  234 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  235 :_map      : Int_t _map_                                            *
# *Entries :       10 : Total  Size=       2623 bytes  File Size  =        384 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  236 :_map.first : UInt_t first[_map_]                                   *
# *Entries :       10 : Total  Size=        987 bytes  File Size  =        402 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  237 :_map.second : SvtxVertex* second[_map_]                            *
# *Entries :       10 : Total  Size=       2239 bytes  File Size  =       1256 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.32     *
# *............................................................................*
# *Branch  :DST#SVTX#PHG4ParticleSvtxMap                                       *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br  238 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  239 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  240 :m_map     : Int_t m_map_                                           *
# *Entries :       10 : Total  Size=       2703 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  241 :m_map.first : Int_t first[m_map_]                                  *
# *Entries :       10 : Total  Size=       7289 bytes  File Size  =       4269 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.57     *
# *............................................................................*
# *Br  242 :m_map.second : map<float,set<unsigned int> > second[m_map_]        *
# *Entries :       10 : Total  Size=      40317 bytes  File Size  =      10333 *
# *Baskets :        6 : Basket Size=       9149 bytes  Compression=   3.84     *
# *............................................................................*
# *Branch  :DST#SVTX#SvtxPHG4ParticleMap                                       *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br  243 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  244 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  245 :m_map     : Int_t m_map_                                           *
# *Entries :       10 : Total  Size=       2703 bytes  File Size  =        388 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br  246 :m_map.first : UInt_t first[m_map_]                                 *
# *Entries :       10 : Total  Size=       5613 bytes  File Size  =       2247 *
# *Baskets :        4 : Basket Size=       9149 bytes  Compression=   2.24     *
# *............................................................................*
# *Br  247 :m_map.second : map<float,set<int> > second[m_map_]                 *
# *Entries :       10 : Total  Size=      90281 bytes  File Size  =      44583 *
# *Baskets :        6 : Basket Size=      15872 bytes  Compression=   2.01     *
# *............................................................................*

# %%
125910931 / 10.
# Out:
# 12591093.1

# %%
captured.stdout
# Out:
# '******************************************************************************\n*Tree    :T         : titled by PHOOL                                        *\n*Entries :       10 : Total =       970048793 bytes  File  Size =  125910931 *\n*        :          : Tree compression factor =   7.70                       *\n******************************************************************************\n*Branch  :DST#Sync                                                           *\n*Entries :       10 : BranchElement (see below)                              *\n*............................................................................*\n*Br    0 :fUniqueID : UInt_t                                                 *\n*Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *\n*Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *\n*............................................................................*\n*Br    1 :fBits     : UInt_t                                                 *\n*Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *\n*Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *\n*............................................................................*\n*Br    2 :eventcounter : Int_t                                               *\n*Entries :       10 : Total  Size=        861 bytes  File Size  =        344 *\n*Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *\n*............................................................................*\n*Br    3 :eventnumber : Int_t                                                *\n*Entries :       10 : Total  Size=        853 bytes  File Size  =        340 *\n*Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *\n*............................................................................*\n*Br    4 :runnumber : Int_t                                                  *\n*Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *\n*Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *\n*............................................................................*\n*Br    5 :segmentnumber : Int_t                                              *\n*Entries :       10 : Total  Size=        869 bytes  File Size  =        348 *\n*Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *\n*............................................................................*\n*Branch  :DST#EventHeader                                                    *\n*Entries :       10 : BranchElement (see below)                              *\n*............................................................................*\n*Br    6 :fUniqueID : UInt_t                                                 *\n*Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *\n*Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *\n*............................................................................*\n*Br    7 :fBits     : UInt_t                                                 *\n*Entries :       10 : Total  Size=        877 bytes  File Size  =        388 *\n*Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *\n*............................................................................*\n*Br    8 :RunNumber : Int_t                                                  *\n*Entries :       10 : Total  Size=        837 bytes  File Size  =        332 *\n*Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *\n*............................................................................*\n*Br    9 :EvtSequence : Int_t                                                *\n*Entries :       10 : Total  Size=        853 bytes  File Size  =        340 *\n*Baskets :        4 : Basket Size=       9149 bytes  Compression=   1.00     *\ ...
