# %%
# imports to write dynamic markdown contents
import os
from IPython.display import display, Markdown, Latex
from IPython.display import HTML

# %%
# turn off/on code for the result HTML page

display(Markdown('*For the result HTML page:* '))
    
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# *For the result HTML page:*
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.24/06

# %%
import uproot

import pandas as pd
import os
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.colors
import numpy as np
import glob
mpl.style.use('seaborn-talk')

# %%
OFFLINE_MAIN = os.getenv("OFFLINE_MAIN")
if OFFLINE_MAIN is not None:
    display(Markdown(f"via sPHENIX software distribution at `{OFFLINE_MAIN}`"))
# Out:
# via sPHENIX software distribution at `/cvmfs/sphenix.sdcc.bnl.gov/gcc-8.3/release/release_new/new.3`

# %%
ROOT.gSystem.Load("libg4dst")
ROOT.gSystem.Load("libfun4all")
# Out:
# 0

# %%
# DST_TRUTH_pythia8_pp_mb_3MHz = ROOT.TFile.Open("/sphenix/sim/sim01/sphnxpro/mdc2/hf_pp200_signal/tracks/charm/DST_TRUTH_pythia8_pp_mb_3MHz-0000000004-00004.root")

# %%
# %%cpp -d
#
# #include <fun4all/Fun4AllDstInputManager.h>
# #include <fun4all/Fun4AllInputManager.h>
# #include <fun4all/Fun4AllServer.h>
# #include <fun4all/SubsysReco.h>
#
# #include <TSystem.h>

# %%
# %%cpp
#
# {
#   Fun4AllServer *se = Fun4AllServer::instance();
#
#   Fun4AllInputManager *in = new Fun4AllDstInputManager("DSTin");
#   in->fileopen("DST_TRUTH_RECO_ANALYSIS-0000000004-00000.root");
#   se->registerInputManager(in);
#
#   se->run(1);
#   se->End();
# }
# Out:
# Fun4AllServer::setRun(): could not get timestamp for run  4, using tics(0) timestamp: Wed Dec 31 19:00:00 1969
# --------------------------------------
#
# List of Nodes in Fun4AllServer:
# Node Tree under TopNode TOP
# TOP (PHCompositeNode)/
#    DST (PHCompositeNode)/
#       EventHeader (IO,EventHeaderv1)
#       HCALIN (PHCompositeNode)/
#          TOWER_CALIB_HCALIN (IO,RawTowerContainer)
#          CLUSTER_HCALIN (IO,RawClusterContainer)
#       HCALOUT (PHCompositeNode)/
#          TOWER_CALIB_HCALOUT (IO,RawTowerContainer)
#          CLUSTER_HCALOUT (IO,RawClusterContainer)
#       GLOBAL (PHCompositeNode)/
#          GlobalVertexMap (IO,GlobalVertexMapv1)
#       CEMC (PHCompositeNode)/
#          TOWER_CALIB_CEMC (IO,RawTowerContainer)
#          CLUSTER_CEMC (IO,RawClusterContainer)
#          CLUSTER_POS_COR_CEMC (IO,RawClusterContainer)
#       PHHepMCGenEventMap (IO,PHHepMCGenEventMap)
#       G4HIT_BH_1 (IO,PHG4HitContainer)
#       G4TruthInfo (IO,PHG4TruthInfoContainer)
#       SVTX (PHCompositeNode)/
#          SvtxTrackMap (IO,SvtxTrackMap_v1)
#          SvtxVertexMap (IO,SvtxVertexMap_v1)
#          PHG4ParticleSvtxMap (IO,PHG4ParticleSvtxMap_v1)
#          SvtxPHG4ParticleMap (IO,SvtxPHG4ParticleMap_v1)
#    RUN (PHCompositeNode)/
#       PHGenIntegral (IO,PHGenIntegralv1)
#       RunHeader (IO,RunHeaderv1)
#       Flags (IO,FlagSavev1)
#       FIELD_CONFIG (IO,PHFieldConfigv1)
#       PIPE (PHCompositeNode)/
#          G4GEOPARAM_PIPE (IO,PdbParameterMapContainer)
#       MVTX (PHCompositeNode)/
#          G4GEOPARAM_MVTX (IO,PdbParameterMapContainer)
#       INTT (PHCompositeNode)/
#          G4GEOPARAM_INTT (IO,PdbParameterMapContainer)
#          DEADMAP_INTT (IO,InttDeadMapv1)
#          G4CELLPARAM_INTT (IO,PdbParameterMap)
#       TPC (PHCompositeNode)/
#          G4GEOPARAM_TPC (IO,PdbParameterMapContainer)
#          G4CELLPARAM_TPC (IO,PdbParameterMap)
#          G4TPCPADPLANE (IO,PdbParameterMap)
#       TPC_ENDCAP (PHCompositeNode)/
#          G4GEOPARAM_TPC_ENDCAP (IO,PdbParameterMapContainer)
#       MICROMEGAS (PHCompositeNode)/
#          G4GEOPARAM_MICROMEGAS (IO,PdbParameterMapContainer)
#       BBC (PHCompositeNode)/
#          G4GEOPARAM_BBC (IO,PdbParameterMapContainer)
#       CEMC_ELECTRONICS (PHCompositeNode)/
#          G4GEOPARAM_CEMC_ELECTRONICS (IO,PdbParameterMapContainer)
#       CEMC_SPT (PHCompositeNode)/
#          G4GEOPARAM_CEMC_SPT (IO,PdbParameterMapContainer)
#       CEMC (PHCompositeNode)/
#          G4GEOPARAM_CEMC (IO,PdbParameterMapContainer)
#          G4CELLPARAM_CEMC (IO,PdbParameterMap)
#          TOWERGEOM_CEMC (IO,RawTowerGeomContainer_Cylinderv1)
#       HCALIN (PHCompositeNode)/
#          G4GEOPARAM_HCALIN (IO,PdbParameterMapContainer)
#          G4CELLPARAM_HCALIN (IO,PdbParameterMap)
#          TOWERPARAM_HCALIN (IO,PdbParameterMap)
#          TOWERGEOM_HCALIN (IO,RawTowerGeomContainer_Cylinderv1)
#       HCALIN_SPT (PHCompositeNode)/
#          G4GEOPARAM_HCALIN_SPT (IO,PdbParameterMapContainer)
#       MAGNET (PHCompositeNode)/
#          G4GEOPARAM_MAGNET (IO,PdbParameterMapContainer)
#       HCALOUT (PHCompositeNode)/
#          G4GEOPARAM_HCALOUT (IO,PdbParameterMapContainer)
#          G4CELLPARAM_HCALOUT (IO,PdbParameterMap)
#          TOWERPARAM_HCALOUT (IO,PdbParameterMap)
#          TOWERGEOM_HCALOUT (IO,RawTowerGeomContainer_Cylinderv1)
#       EPD (PHCompositeNode)/
#          G4GEOPARAM_EPD (IO,PdbParameterMapContainer)
#       G4GEOPARAM_BH_1 (IO,PdbParameterMapContainer)
#       CYLINDERGEOM_BH_1 (IO,PHG4CylinderGeomContainer)
#       BH_FORWARD_PLUS (PHCompositeNode)/
#          G4GEOPARAM_BH_FORWARD_PLUS (IO,PdbParameterMapContainer)
#       BH_FORWARD_NEG (PHCompositeNode)/
#          G4GEOPARAM_BH_FORWARD_NEG (IO,PdbParameterMapContainer)
#       CYLINDERGEOM_MVTX (IO,PHG4CylinderGeomContainer)
#       CYLINDERGEOM_INTT (IO,PHG4CylinderGeomContainer)
#       CYLINDERGEOM_MICROMEGAS_FULL (IO,PHG4CylinderGeomContainer)
#       CYLINDERGEOM_CEMC (IO,PHG4CylinderGeomContainer)
#       GEOMETRY_IO (IO,PHGeomIOTGeo)
#       CYLINDERCELLGEOM_CEMC (IO,PHG4CylinderCellGeomContainer)
#       eclus_Recalibration_CEMC (IO,PdbParameterMap)
#       ecore_Recalibration_CEMC (IO,PdbParameterMap)
#       CYLINDERCELLGEOM_SVTX (IO,PHG4CylinderCellGeomContainer)
#    PAR (PHCompositeNode)/
# Warning in <TClass::Init>: no dictionary for class pair<int,PHG4CylinderGeom_Spacalv3::geom_tower> is available

# %%
ROOT.gFile.ls()
# Out:
# TFile**		./DST_TRUTH_RECO_ANALYSIS-0000000004-00000.root	titled by PHOOL
#  TFile*		./DST_TRUTH_RECO_ANALYSIS-0000000004-00000.root	titled by PHOOL
#   OBJ: TTree	T0x8113640	titled by PHOOL : 0 at: 0x2d43d80
#   KEY: TTree	T;1	titled by PHOOL
#   KEY: TTree	T1;1	titled by PHOOL

# %%
# %%capture captured

ROOT.gFile.T.Print()
# Out:
# ******************************************************************************
# *Tree    :T         : titled by PHOOL                                        *
# *Entries :       10 : Total =        49788642 bytes  File  Size =   19450627 *
# *        :          : Tree compression factor =   2.56                       *
# ******************************************************************************
# *Branch  :DST#EventHeader                                                    *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br    0 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        618 bytes  File Size  =         94 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.20     *
# *............................................................................*
# *Br    1 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        646 bytes  File Size  =        123 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.28     *
# *............................................................................*
# *Br    2 :RunNumber : Int_t                                                  *
# *Entries :       10 : Total  Size=        618 bytes  File Size  =         97 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.16     *
# *............................................................................*
# *Br    3 :EvtSequence : Int_t                                                *
# *Entries :       10 : Total  Size=        628 bytes  File Size  =        115 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    4 :m_IntEventProperties : Int_t m_IntEventProperties_                 *
# *Entries :       10 : Total  Size=       2564 bytes  File Size  =        133 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.29     *
# *............................................................................*
# *Br    5 :m_IntEventProperties.first : string first[m_IntEventProperties_]   *
# *Entries :       10 : Total  Size=        877 bytes  File Size  =        147 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.35     *
# *............................................................................*
# *Br    6 :m_IntEventProperties.second : Long_t second[m_IntEventProperties_] *
# *Entries :       10 : Total  Size=        822 bytes  File Size  =        119 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.17     *
# *............................................................................*
# *Br    7 :m_FloatEventProperties : Int_t m_FloatEventProperties_             *
# *Entries :       10 : Total  Size=       2599 bytes  File Size  =        135 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.29     *
# *............................................................................*
# *Br    8 :m_FloatEventProperties.first :                                     *
# *         | string first[m_FloatEventProperties_]                            *
# *Entries :       10 : Total  Size=        891 bytes  File Size  =        149 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.34     *
# *............................................................................*
# *Br    9 :m_FloatEventProperties.second :                                    *
# *         | Float_t second[m_FloatEventProperties_]                          *
# *Entries :       10 : Total  Size=        836 bytes  File Size  =        121 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.17     *
# *............................................................................*
# *Branch  :DST#HCALIN#TOWER_CALIB_HCALIN                                      *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   10 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        618 bytes  File Size  =         94 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.20     *
# *............................................................................*
# *Br   11 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        646 bytes  File Size  =        123 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.28     *
# *............................................................................*
# *Br   12 :_caloid   : Int_t                                                  *
# *Entries :       10 : Total  Size=        608 bytes  File Size  =         95 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.17     *
# *............................................................................*
# *Br   13 :_towers   : Int_t _towers_                                         *
# *Entries :       10 : Total  Size=       2452 bytes  File Size  =        143 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.11     *
# *............................................................................*
# *Br   14 :_towers.first : UInt_t first[_towers_]                             *
# *Entries :       10 : Total  Size=      11014 bytes  File Size  =       5183 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.01     *
# *............................................................................*
# *Br   15 :_towers.second : RawTower* second[_towers_]                        *
# *Entries :       10 : Total  Size=     255955 bytes  File Size  =      16323 *
# *Baskets :       10 : Basket Size=      32000 bytes  Compression=  15.64     *
# *............................................................................*
# *Branch  :DST#HCALIN#CLUSTER_HCALIN                                          *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   16 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        618 bytes  File Size  =         94 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.20     *
# *............................................................................*
# *Br   17 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        646 bytes  File Size  =        123 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.28     *
# *............................................................................*
# *Br   18 :_clusters : Int_t _clusters_                                       *
# *Entries :       10 : Total  Size=       2476 bytes  File Size  =        142 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.13     *
# *............................................................................*
# *Br   19 :_clusters.first : UInt_t first[_clusters_]                         *
# *Entries :       10 : Total  Size=        928 bytes  File Size  =        159 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.98     *
# *............................................................................*
# *Br   20 :_clusters.second : RawCluster* second[_clusters_]                  *
# *Entries :       10 : Total  Size=       5956 bytes  File Size  =       1674 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   3.19     *
# *............................................................................*
# *Branch  :DST#HCALOUT#TOWER_CALIB_HCALOUT                                    *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   21 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        618 bytes  File Size  =         94 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.20     *
# *............................................................................*
# *Br   22 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        646 bytes  File Size  =        123 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.28     *
# *............................................................................*
# *Br   23 :_caloid   : Int_t                                                  *
# *Entries :       10 : Total  Size=        608 bytes  File Size  =         95 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.17     *
# *............................................................................*
# *Br   24 :_towers   : Int_t _towers_                                         *
# *Entries :       10 : Total  Size=       2452 bytes  File Size  =        144 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.10     *
# *............................................................................*
# *Br   25 :_towers.first : UInt_t first[_towers_]                             *
# *Entries :       10 : Total  Size=      10974 bytes  File Size  =       5194 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.00     *
# *............................................................................*
# *Br   26 :_towers.second : RawTower* second[_towers_]                        *
# *Entries :       10 : Total  Size=     254455 bytes  File Size  =      15415 *
# *Baskets :       10 : Basket Size=      32000 bytes  Compression=  16.47     *
# *............................................................................*
# *Branch  :DST#HCALOUT#CLUSTER_HCALOUT                                        *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   27 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        618 bytes  File Size  =         94 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.20     *
# *............................................................................*
# *Br   28 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        646 bytes  File Size  =        123 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.28     *
# *............................................................................*
# *Br   29 :_clusters : Int_t _clusters_                                       *
# *Entries :       10 : Total  Size=       2476 bytes  File Size  =        144 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.12     *
# *............................................................................*
# *Br   30 :_clusters.first : UInt_t first[_clusters_]                         *
# *Entries :       10 : Total  Size=        976 bytes  File Size  =        174 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.09     *
# *............................................................................*
# *Br   31 :_clusters.second : RawCluster* second[_clusters_]                  *
# *Entries :       10 : Total  Size=       7123 bytes  File Size  =       1830 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   3.56     *
# *............................................................................*
# *Branch  :DST#GLOBAL#GlobalVertexMap                                         *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   32 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        618 bytes  File Size  =         94 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.20     *
# *............................................................................*
# *Br   33 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        646 bytes  File Size  =        123 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.28     *
# *............................................................................*
# *Br   34 :_map      : Int_t _map_                                            *
# *Entries :       10 : Total  Size=       2407 bytes  File Size  =        121 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.29     *
# *............................................................................*
# *Br   35 :_map.first : UInt_t first[_map_]                                   *
# *Entries :       10 : Total  Size=        745 bytes  File Size  =        123 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.32     *
# *............................................................................*
# *Br   36 :_map.second : GlobalVertex* second[_map_]                          *
# *Entries :       10 : Total  Size=       1900 bytes  File Size  =        407 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   3.23     *
# *............................................................................*
# *Branch  :DST#CEMC#TOWER_CALIB_CEMC                                          *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   37 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        618 bytes  File Size  =         94 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.20     *
# *............................................................................*
# *Br   38 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        646 bytes  File Size  =        123 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.28     *
# *............................................................................*
# *Br   39 :_caloid   : Int_t                                                  *
# *Entries :       10 : Total  Size=        608 bytes  File Size  =         95 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.17     *
# *............................................................................*
# *Br   40 :_towers   : Int_t _towers_                                         *
# *Entries :       10 : Total  Size=       2452 bytes  File Size  =        146 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.09     *
# *............................................................................*
# *Br   41 :_towers.first : UInt_t first[_towers_]                             *
# *Entries :       10 : Total  Size=      32230 bytes  File Size  =      19123 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.65     *
# *............................................................................*
# *Br   42 :_towers.second : RawTower* second[_towers_]                        *
# *Entries :       10 : Total  Size=     778339 bytes  File Size  =      70424 *
# *Baskets :       10 : Basket Size=      32000 bytes  Compression=  11.04     *
# *............................................................................*
# *Branch  :DST#CEMC#CLUSTER_CEMC                                              *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   43 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        618 bytes  File Size  =         94 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.20     *
# *............................................................................*
# *Br   44 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        646 bytes  File Size  =        123 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.28     *
# *............................................................................*
# *Br   45 :_clusters : Int_t _clusters_                                       *
# *Entries :       10 : Total  Size=       2496 bytes  File Size  =        148 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.09     *
# *............................................................................*
# *Br   46 :_clusters.first : UInt_t first[_clusters_]                         *
# *Entries :       10 : Total  Size=      29308 bytes  File Size  =       1773 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  16.18     *
# *............................................................................*
# *Br   47 :_clusters.second : RawCluster* second[_clusters_]                  *
# *Entries :       10 : Total  Size=     743289 bytes  File Size  =     186521 *
# *Baskets :       10 : Basket Size=      32000 bytes  Compression=   3.98     *
# *............................................................................*
# *Branch  :DST#CEMC#CLUSTER_POS_COR_CEMC                                      *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   48 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        618 bytes  File Size  =         94 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.20     *
# *............................................................................*
# *Br   49 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        646 bytes  File Size  =        123 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.28     *
# *............................................................................*
# *Br   50 :_clusters : Int_t _clusters_                                       *
# *Entries :       10 : Total  Size=       2496 bytes  File Size  =        148 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.09     *
# *............................................................................*
# *Br   51 :_clusters.first : UInt_t first[_clusters_]                         *
# *Entries :       10 : Total  Size=      29308 bytes  File Size  =       1773 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  16.18     *
# *............................................................................*
# *Br   52 :_clusters.second : RawCluster* second[_clusters_]                  *
# *Entries :       10 : Total  Size=     743289 bytes  File Size  =     209950 *
# *Baskets :       10 : Basket Size=      32000 bytes  Compression=   3.54     *
# *............................................................................*
# *Branch  :DST#PHHepMCGenEventMap                                             *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   53 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        618 bytes  File Size  =         94 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.20     *
# *............................................................................*
# *Br   54 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        646 bytes  File Size  =        123 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.28     *
# *............................................................................*
# *Br   55 :_map      : Int_t _map_                                            *
# *Entries :       10 : Total  Size=       2399 bytes  File Size  =        135 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.16     *
# *............................................................................*
# *Br   56 :_map.first : Int_t first[_map_]                                    *
# *Entries :       10 : Total  Size=       4009 bytes  File Size  =        357 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   9.60     *
# *............................................................................*
# *Br   57 :_map.second : PHHepMCGenEvent* second[_map_]                       *
# *Entries :       10 : Total  Size=   15012693 bytes  File Size  =    4481032 *
# *Baskets :       10 : Basket Size=      32000 bytes  Compression=   3.35     *
# *............................................................................*
# *Branch  :DST#G4HIT_BH_1                                                     *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   58 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        618 bytes  File Size  =         94 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.20     *
# *............................................................................*
# *Br   59 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        646 bytes  File Size  =        123 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.28     *
# *............................................................................*
# *Br   60 :id        : Int_t                                                  *
# *Entries :       10 : Total  Size=        583 bytes  File Size  =         90 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.18     *
# *............................................................................*
# *Br   61 :hitmap    : Int_t hitmap_                                          *
# *Entries :       10 : Total  Size=       2415 bytes  File Size  =        148 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.07     *
# *............................................................................*
# *Br   62 :hitmap.first : ULong64_t first[hitmap_]                            *
# *Entries :       10 : Total  Size=      41755 bytes  File Size  =       3061 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=  13.45     *
# *............................................................................*
# *Br   63 :hitmap.second : PHG4Hit* second[hitmap_]                           *
# *Entries :       10 : Total  Size=     692674 bytes  File Size  =     263322 *
# *Baskets :       10 : Basket Size=      32000 bytes  Compression=   2.63     *
# *............................................................................*
# *Br   64 :layers    : set<unsigned int>                                      *
# *Entries :       10 : Total  Size=        751 bytes  File Size  =        133 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.94     *
# *............................................................................*
# *Branch  :DST#G4TruthInfo                                                    *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   65 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        618 bytes  File Size  =         94 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.20     *
# *............................................................................*
# *Br   66 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        646 bytes  File Size  =        123 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.28     *
# *............................................................................*
# *Br   67 :particlemap : Int_t particlemap_                                   *
# *Entries :       10 : Total  Size=       2517 bytes  File Size  =        160 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.02     *
# *............................................................................*
# *Br   68 :particlemap.first : Int_t first[particlemap_]                      *
# *Entries :       10 : Total  Size=     474835 bytes  File Size  =     290752 *
# *Baskets :       10 : Basket Size=      32000 bytes  Compression=   1.63     *
# *............................................................................*
# *Br   69 :particlemap.second : PHG4Particle* second[particlemap_]            *
# *Entries :       10 : Total  Size=   16248524 bytes  File Size  =    5536086 *
# *Baskets :       10 : Basket Size=      32000 bytes  Compression=   2.93     *
# *............................................................................*
# *Br   70 :vtxmap    : Int_t vtxmap_                                          *
# *Entries :       10 : Total  Size=       2442 bytes  File Size  =        153 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.03     *
# *............................................................................*
# *Br   71 :vtxmap.first : Int_t first[vtxmap_]                                *
# *Entries :       10 : Total  Size=     324047 bytes  File Size  =     208477 *
# *Baskets :       10 : Basket Size=      32000 bytes  Compression=   1.55     *
# *............................................................................*
# *Br   72 :vtxmap.second : PHG4VtxPoint* second[vtxmap_]                      *
# *Entries :       10 : Total  Size=    5807595 bytes  File Size  =    2861024 *
# *Baskets :       10 : Basket Size=      32000 bytes  Compression=   2.03     *
# *............................................................................*
# *Br   73 :showermap : Int_t showermap_                                       *
# *Entries :       10 : Total  Size=       2437 bytes  File Size  =        143 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.13     *
# *............................................................................*
# *Br   74 :showermap.first : Int_t first[showermap_]                          *
# *Entries :       10 : Total  Size=       2352 bytes  File Size  =        414 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   4.20     *
# *............................................................................*
# *Br   75 :showermap.second : PHG4Shower* second[showermap_]                  *
# *Entries :       10 : Total  Size=     116103 bytes  File Size  =      36156 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   3.19     *
# *............................................................................*
# *Br   76 :particle_embed_flags : Int_t particle_embed_flags_                 *
# *Entries :       10 : Total  Size=       2562 bytes  File Size  =        165 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.04     *
# *............................................................................*
# *Br   77 :particle_embed_flags.first : Int_t first[particle_embed_flags_]    *
# *Entries :       10 : Total  Size=     101343 bytes  File Size  =      22294 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   4.52     *
# *............................................................................*
# *Br   78 :particle_embed_flags.second : Int_t second[particle_embed_flags_]  *
# *Entries :       10 : Total  Size=     101351 bytes  File Size  =       3958 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=  25.43     *
# *............................................................................*
# *Br   79 :vertex_embed_flags : Int_t vertex_embed_flags_                     *
# *Entries :       10 : Total  Size=       2532 bytes  File Size  =        152 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.12     *
# *............................................................................*
# *Br   80 :vertex_embed_flags.first : Int_t first[vertex_embed_flags_]        *
# *Entries :       10 : Total  Size=       4107 bytes  File Size  =        359 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   9.58     *
# *............................................................................*
# *Br   81 :vertex_embed_flags.second : Int_t second[vertex_embed_flags_]      *
# *Entries :       10 : Total  Size=       4112 bytes  File Size  =        377 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   9.13     *
# *............................................................................*
# *Branch  :DST#SVTX#SvtxTrackMap                                              *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   82 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        618 bytes  File Size  =         94 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.20     *
# *............................................................................*
# *Br   83 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        646 bytes  File Size  =        123 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.28     *
# *............................................................................*
# *Br   84 :_map      : Int_t _map_                                            *
# *Entries :       10 : Total  Size=       2408 bytes  File Size  =        138 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.13     *
# *............................................................................*
# *Br   85 :_map.first : UInt_t first[_map_]                                   *
# *Entries :       10 : Total  Size=       5357 bytes  File Size  =       1532 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   3.12     *
# *............................................................................*
# *Br   86 :_map.second : SvtxTrack* second[_map_]                             *
# *Entries :       10 : Total  Size=    7721110 bytes  File Size  =    5126292 *
# *Baskets :       10 : Basket Size=      32000 bytes  Compression=   1.51     *
# *............................................................................*
# *Branch  :DST#SVTX#SvtxVertexMap                                             *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   87 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        618 bytes  File Size  =         94 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.20     *
# *............................................................................*
# *Br   88 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        646 bytes  File Size  =        123 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.28     *
# *............................................................................*
# *Br   89 :_map      : Int_t _map_                                            *
# *Entries :       10 : Total  Size=       2395 bytes  File Size  =        121 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.29     *
# *............................................................................*
# *Br   90 :_map.first : UInt_t first[_map_]                                   *
# *Entries :       10 : Total  Size=        745 bytes  File Size  =        123 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.32     *
# *............................................................................*
# *Br   91 :_map.second : SvtxVertex* second[_map_]                            *
# *Entries :       10 : Total  Size=       1994 bytes  File Size  =        748 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.88     *
# *............................................................................*
# *Branch  :DST#SVTX#PHG4ParticleSvtxMap                                       *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   92 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        618 bytes  File Size  =         94 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.20     *
# *............................................................................*
# *Br   93 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        646 bytes  File Size  =        123 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.28     *
# *............................................................................*
# *Br   94 :m_map     : Int_t m_map_                                           *
# *Entries :       10 : Total  Size=       2472 bytes  File Size  =        141 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.11     *
# *............................................................................*
# *Br   95 :m_map.first : Int_t first[m_map_]                                  *
# *Entries :       10 : Total  Size=       7040 bytes  File Size  =       4020 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.60     *
# *............................................................................*
# *Br   96 :m_map.second : map<float,set<unsigned int> > second[m_map_]        *
# *Entries :       10 : Total  Size=      39981 bytes  File Size  =       9461 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   4.16     *
# *............................................................................*
# *Branch  :DST#SVTX#SvtxPHG4ParticleMap                                       *
# *Entries :       10 : BranchElement (see below)                              *
# *............................................................................*
# *Br   97 :fUniqueID : UInt_t                                                 *
# *Entries :       10 : Total  Size=        618 bytes  File Size  =         94 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.20     *
# *............................................................................*
# *Br   98 :fBits     : UInt_t                                                 *
# *Entries :       10 : Total  Size=        646 bytes  File Size  =        123 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.28     *
# *............................................................................*
# *Br   99 :m_map     : Int_t m_map_                                           *
# *Entries :       10 : Total  Size=       2472 bytes  File Size  =        140 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.12     *
# *............................................................................*
# *Br  100 :m_map.first : UInt_t first[m_map_]                                 *
# *Entries :       10 : Total  Size=       5364 bytes  File Size  =       1534 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   3.11     *
# *............................................................................*
# *Br  101 :m_map.second : map<float,set<int> > second[m_map_]                 *
# *Entries :       10 : Total  Size=      90113 bytes  File Size  =      44968 *
# *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.99     *
# *............................................................................*

# %%
125910931 / 10.
# Out:
# 12591093.1

# %%
captured.stdout
# Out:
# '******************************************************************************\n*Tree    :T         : titled by PHOOL                                        *\n*Entries :       10 : Total =        49788642 bytes  File  Size =   19450627 *\n*        :          : Tree compression factor =   2.56                       *\n******************************************************************************\n*Branch  :DST#EventHeader                                                    *\n*Entries :       10 : BranchElement (see below)                              *\n*............................................................................*\n*Br    0 :fUniqueID : UInt_t                                                 *\n*Entries :       10 : Total  Size=        618 bytes  File Size  =         94 *\n*Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.20     *\n*............................................................................*\n*Br    1 :fBits     : UInt_t                                                 *\n*Entries :       10 : Total  Size=        646 bytes  File Size  =        123 *\n*Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.28     *\n*............................................................................*\n*Br    2 :RunNumber : Int_t                                                  *\n*Entries :       10 : Total  Size=        618 bytes  File Size  =         97 *\n*Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.16     *\n*............................................................................*\n*Br    3 :EvtSequence : Int_t                                                *\n*Entries :       10 : Total  Size=        628 bytes  File Size  =        115 *\n*Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.00     *\n*............................................................................*\n*Br    4 :m_IntEventProperties : Int_t m_IntEventProperties_                 *\n*Entries :       10 : Total  Size=       2564 bytes  File Size  =        133 *\n*Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.29     *\n*............................................................................*\n*Br    5 :m_IntEventProperties.first : string first[m_IntEventProperties_]   *\n*Entries :       10 : Total  Size=        877 bytes  File Size  =        147 *\n*Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.35     *\n*............................................................................*\n*Br    6 :m_IntEventProperties.second : Long_t second[m_IntEventProperties_] *\n*Entries :       10 : Total  Size=        822 bytes  File Size  =        119 *\n*Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.17     *\n*............................................................................*\n*Br    7 :m_FloatEventProperties : Int_t m_FloatEventProperties_             *\n*Entries :       10 : Total  Size=       2599 bytes  File Size  =        135 *\n*Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.29     *\n*............................................................................*\n*Br    8 :m_FloatEventProperties.first :                                     *\n*         | string first[m_FloatEventProperties_]                            *\n*Entries :       10 : Total  Size=        891 bytes  File Size  =        149 *\n*Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.34     *\n*............................................................................*\n*Br    9 :m_FloatEventProperties.second :                                    *\n*         | Float_t second[m_FloatEventProperties_]                          *\n*Entries :       10 : Total  Size=        836 bytes  File Size  =        121 *\n*Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.17     *\n*............................................................................*\ ...
